# %%
import numpy as np
import pandas as pd

# %%
data_movies = pd.read_csv("/Users/sayedrizwan/Downloads/movies.csv")
data_links = pd.read_csv("/Users/sayedrizwan/Downloads/links.csv")
data_tags = pd.read_csv("/Users/sayedrizwan/Downloads/tags.csv")
data_ratings = pd.read_csv("/Users/sayedrizwan/Downloads/ratings.csv")

# %%
data_movies.shape
# Out:
# (9742, 3)

# %%
data_ratings.shape
# Out:
# (100836, 4)

# %%
data_ratings.head
# Out:
# <bound method NDFrame.head of         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]>

# %%
data_ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
data_movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
data_ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
data_links.columns
# Out:
# Index(['movieId', 'imdbId', 'tmdbId'], dtype='object')

# %%
data_tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
merged_df.head
# Out:
# <bound method NDFrame.head of Empty DataFrame
# Columns: []
# Index: []>

# %%
data_tags.head
# Out:
# <bound method NDFrame.head of       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]>

# %%
data_tags.head(100)
# Out:
#     userId  movieId              tag   timestamp
# 0        2    60756            funny  1445714994
# 1        2    60756  Highly quotable  1445714996
# 2        2    60756     will ferrell  1445714992
# 3        2    89774     Boxing story  1445715207
# 4        2    89774              MMA  1445715200
# ..     ...      ...              ...         ...
# 95      62     6541     captain nemo  1525554054
# 96      62     6541       comic book  1525554028
# 97      62     6541           gothic  1525554056
# 98      62     6541      Peta Wilson  1525554040
# 99      62     6541     Sean Connery  1525554026
#
# [100 rows x 4 columns]

# %%
data_ratings.groupby('movieId').count().sort_values(by='rating', ascending=False)
# Out:
#          userId  rating  timestamp
# movieId
# 356         329     329        329
# 318         317     317        317
# 296         307     307        307
# 593         279     279        279
# 2571        278     278        278
# ...         ...     ...        ...
# 4093          1       1          1
# 4089          1       1          1
# 58351         1       1          1
# 4083          1       1          1
# 193609        1       1          1
#
# [9724 rows x 3 columns]

# %%
data_ratings.head(100)
# Out:
#     userId  movieId  rating  timestamp
# 0        1        1     4.0  964982703
# 1        1        3     4.0  964981247
# 2        1        6     4.0  964982224
# 3        1       47     5.0  964983815
# 4        1       50     5.0  964982931
# ..     ...      ...     ...        ...
# 95       1     1445     3.0  964984112
# 96       1     1473     4.0  964980875
# 97       1     1500     4.0  964980985
# 98       1     1517     5.0  964981107
# 99       1     1552     4.0  964982620
#
# [100 rows x 4 columns]

# %%
data_movies[data_movies['movieId'] == 356]
# Out:
#      movieId                title                    genres
# 314      356  Forrest Gump (1994)  Comedy|Drama|Romance|War

# %%
data_movies[data_movies['title'] == 'Matrix, The (1999)']
# Out:
#       movieId               title                  genres
# 1939     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller

# %%
data_tags[data_tags['movieId'] == 2571]
# Out:
#       userId  movieId                 tag   timestamp
# 815      424     2571        martial arts  1457842912
# 816      424     2571              sci-fi  1457842899
# 1646     474     2571  alternate universe  1137204991
# 2794     537     2571          philosophy  1424141098
# 2795     537     2571    post apocalyptic  1424141101

# %%
data_movies[data_movies['title'] == "Terminator 2: Judgment Day (1991)"]
# Out:
#      movieId                              title         genres
# 507      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi

# %%
data_ratings.groupby('movieId').describe()
# Out:
#         userId                                                             \
#          count        mean         std    min    25%    50%    75%    max
# movieId
# 1        215.0  306.530233  180.419754    1.0  155.5  290.0  468.5  610.0
# 2        110.0  329.554545  180.668513    6.0  171.0  322.5  481.5  608.0
# 3         52.0  283.596154  193.026185    1.0  101.5  288.5  459.5  608.0
# 4          7.0  219.857143  220.883400    6.0   49.0  162.0  336.5  600.0
# 5         49.0  299.571429  184.997072    6.0  120.0  288.0  470.0  604.0
# ...        ...         ...         ...    ...    ...    ...    ...    ...
# 193581     1.0  184.000000         NaN  184.0  184.0  184.0  184.0  184.0
# 193583     1.0  184.000000         NaN  184.0  184.0  184.0  184.0  184.0
# 193585     1.0  184.000000         NaN  184.0  184.0  184.0  184.0  184.0
# 193587     1.0  184.000000         NaN  184.0  184.0  184.0  184.0  184.0
# ...

# %%
data_ratings[data_ratings['movieId'] == 589]['rating'].mean()
# Out:
# 3.970982142857143

# %%
data_movies[data_movies['title'] == "Fight Club (1999)"]
# Out:
#       movieId              title                       genres
# 2226     2959  Fight Club (1999)  Action|Crime|Drama|Thriller

# %%
data_ratings[data_ratings['movieId'] == 2959]['rating']
# Out:
# 192      5.0
# 458      2.0
# 1134     0.5
# 1479     2.5
# 1635     3.5
#         ...
# 95893    5.0
# 96788    4.0
# 97835    5.0
# 99107    5.0
# 99699    5.0
# Name: rating, Length: 218, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
movie_2959 = data_ratings[data_ratings['movieId'] == 2959]['rating']
plt.bar(movie_2959.index, movie_2959)
plt.xlabel('User ID')
plt.ylabel('Rating')
plt.title('Ratings for Movie 2959')
plt.show()

# %%
y.head(100)
# Out:
#      userId  movieId  rating  timestamp
# 0         1        1     4.0  964982703
# 1         1        3     4.0  964981247
# 2         1        6     4.0  964982224
# 3         1       47     5.0  964983815
# 4         1       50     5.0  964982931
# ..      ...      ...     ...        ...
# 178       1     2692     5.0  964981855
# 179       1     2700     5.0  964980985
# 180       1     2716     5.0  964983414
# 182       1     2797     4.0  964981710
# 184       1     2858     5.0  964980868
#
# [100 rows x 4 columns]

# %%
merged_df = pd.merge(y, data_movies, on='movieId', how='inner')

# %%
merged_df.groupby(['movieId']).count().sort_values(by = 'rating', ascending =False)
# Out:
#          userId  rating  timestamp  title  genres
# movieId
# 356         329     329        329    329     329
# 318         317     317        317    317     317
# 296         307     307        307    307     307
# 593         279     279        279    279     279
# 2571        278     278        278    278     278
# ...         ...     ...        ...    ...     ...
# 4239         51      51         51     51      51
# 4776         51      51         51     51      51
# 4848         51      51         51     51      51
# 145          51      51         51     51      51
# 1645         51      51         51     51      51
#
# [436 rows x 5 columns]

# %% [raw]
# z = merged_df.groupby('movieId')
# print(z)

# %%
filtered = data_ratings.groupby('movieId')['rating'].describe()

# %%
merged = pd.merge(filtered, data_movies, on='movieId', how='inner')

# %%
merged1 = merged[merged['count']>50]

# %%
merged_df = pd.merge(data_movies, filtered, on='movieId', how='inner')
merged_df
merged_df1 = merged_df[merged_df['count']>50]
merged_df1
# Out:
#       movieId                             title  \
# 0           1                  Toy Story (1995)
# 1           2                    Jumanji (1995)
# 2           3           Grumpier Old Men (1995)
# 5           6                       Heat (1995)
# 6           7                    Sabrina (1995)
# ...       ...                               ...
# 8287   106782   Wolf of Wall Street, The (2013)
# 8354   109374  Grand Budapest Hotel, The (2014)
# 8358   109487               Interstellar (2014)
# 8457   112852    Guardians of the Galaxy (2014)
# 8673   122904                   Deadpool (2016)
#
#                                            genres  count      mean       std  \
# 0     Adventure|Animation|Children|Comedy|Fantasy  215.0  3.920930  0.834859
# 1                      Adventure|Children|Fantasy  110.0  3.431818  0.881713
# 2                                  Comedy|Romance   52.0  3.259615  1.054823
# ...

# %%
merged_df1.sort_values(by = 'mean', ascending = False)
# Out:
#       movieId                                              title  \
# 277       318                   Shawshank Redemption, The (1994)
# 659       858                              Godfather, The (1972)
# 2224     2959                                  Fight Club (1999)
# 974      1276                              Cool Hand Luke (1967)
# 602       750  Dr. Strangelove or: How I Learned to Stop Worr...
# ...       ...                                                ...
# 144       172                             Johnny Mnemonic (1995)
# 145       173                                 Judge Dredd (1995)
# 376       432  City Slickers II: The Legend of Curly's Gold (...
# 379       435                                   Coneheads (1993)
# 2028     2701                              Wild Wild West (1999)
#
#                             genres  count      mean       std  min   25%  50%  \
# 277                    Crime|Drama  317.0  4.429022  0.713019  1.0  4.00  4.5
# ...

# %%
merged_df1[merged_df1['genres'].str.contains('Sci-Fi', case=False, na=False)].sort_values(by='count', ascending=False)
# Out:
#       movieId                                              title  \
# 1938     2571                                 Matrix, The (1999)
# 224       260          Star Wars: Episode IV - A New Hope (1977)
# 418       480                               Jurassic Park (1993)
# 507       589                  Terminator 2: Judgment Day (1991)
# 897      1196  Star Wars: Episode V - The Empire Strikes Back...
# ...       ...                                                ...
# 8673   122904                                    Deadpool (2016)
# 144       172                             Johnny Mnemonic (1995)
# 2028     2701                              Wild Wild West (1999)
# 559       673                                   Space Jam (1996)
# 6192    45499                       X-Men: The Last Stand (2006)
#
#                                                  genres  count      mean  \
# 1938                             Action|Sci-Fi|Thriller  278.0  4.192446
# ...

# %%
data_links.shape
# Out:
# (9742, 3)

# %%
data_links.sort_values(by = 'imdbId', ascending = False)
# Out:
#       movieId   imdbId    tmdbId
# 9740   193587  8391976  483455.0
# 9695   184791  7924798  502616.0
# 9677   183227  7808620  494368.0
# 9675   183197  7807952  488223.0
# 9671   182749  7738550  487156.0
# ...       ...      ...       ...
# 6863    62383     6333   30266.0
# 4743     7065     4972     618.0
# 9020   140541      516  143634.0
# 6355    49389      439    5698.0
# 5868    32898      417     775.0
#
# [9742 rows x 3 columns]

# %%
# Out:
#     userId  movieId              tag   timestamp
# 0        2    60756            funny  1445714994
# 1        2    60756  Highly quotable  1445714996
# 2        2    60756     will ferrell  1445714992
# 3        2    89774     Boxing story  1445715207
# 4        2    89774              MMA  1445715200
# ..     ...      ...              ...         ...
# 95      62     6541     captain nemo  1525554054
# 96      62     6541       comic book  1525554028
# 97      62     6541           gothic  1525554056
# 98      62     6541      Peta Wilson  1525554040
# 99      62     6541     Sean Connery  1525554026
#
# [100 rows x 4 columns]

# %%
data_movies[data_movies['title'] == "X-Men: The Last Stand (2006)"]
# Out:
#       movieId                         title                  genres
# 6209    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller

# %%
merged_df = pd.merge(data_movies, filtered, on='movieId', how='inner')

# %%
merged_df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9719   193581  Black Butler: Book of the Atlantic (2017)
# 9720   193583               No Game No Life: Zero (2017)
# 9721   193585                               Flint (2017)
# 9722   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9723   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres  count      mean       std  \
# 0     Adventure|Animation|Children|Comedy|Fantasy  215.0  3.920930  0.834859
# 1                      Adventure|Children|Fantasy  110.0  3.431818  0.881713
# ...

# %%
merged_final = pd.merge(merged_df1, data_links, on='movieId', how='inner')
merged_final
# Out:
#      movieId                             title  \
# 0          1                  Toy Story (1995)
# 1          2                    Jumanji (1995)
# 2          3           Grumpier Old Men (1995)
# 3          6                       Heat (1995)
# 4          7                    Sabrina (1995)
# ..       ...                               ...
# 431   106782   Wolf of Wall Street, The (2013)
# 432   109374  Grand Budapest Hotel, The (2014)
# 433   109487               Interstellar (2014)
# 434   112852    Guardians of the Galaxy (2014)
# 435   122904                   Deadpool (2016)
#
#                                           genres  count      mean       std  \
# 0    Adventure|Animation|Children|Comedy|Fantasy  215.0  3.920930  0.834859
# 1                     Adventure|Children|Fantasy  110.0  3.431818  0.881713
# 2                                 Comedy|Romance   52.0  3.259615  1.054823
# 3                          Action|Crime|Thriller  102.0  3.946078  0.817224
# ...

# %%
merged_final.sort_values(by = 'imdbId', ascending = False)
# Out:
#      movieId                                   title  \
# 432   109374        Grand Budapest Hotel, The (2014)
# 434   112852          Guardians of the Galaxy (2014)
# 430    99114                 Django Unchained (2012)
# 426    81845               King's Speech, The (2010)
# 435   122904                         Deadpool (2016)
# ..       ...                                     ...
# 123      923                     Citizen Kane (1941)
# 102      596                        Pinocchio (1940)
# 171     1282                         Fantasia (1940)
# 122      919                Wizard of Oz, The (1939)
# 100      594  Snow White and the Seven Dwarfs (1937)
#
#                                        genres  count      mean       std  min  \
# 432                              Comedy|Drama   52.0  3.778846  0.871181  0.5
# 434                   Action|Adventure|Sci-Fi   59.0  4.050847  0.839206  1.0
# 430                      Action|Drama|Western   71.0  3.943662  0.908489  1.0
# ...

# %%
merged_final[merged_final['genres'].str.contains('Sci-Fi', case=False, na=False)].sort_values(by='imdbId', ascending=False)
# Out:
#      movieId                                      title  \
# 434   112852             Guardians of the Galaxy (2014)
# 435   122904                            Deadpool (2016)
# 428    91500                    The Hunger Games (2012)
# 424    79132                           Inception (2010)
# 417    70286                          District 9 (2009)
# ..       ...                                        ...
# 287     3471  Close Encounters of the Third Kind (1977)
# 254     2657      Rocky Horror Picture Show, The (1975)
# 147     1206                 Clockwork Orange, A (1971)
# 246     2529                  Planet of the Apes (1968)
# 124      924               2001: A Space Odyssey (1968)
#
#                                               genres  count      mean  \
# 434                          Action|Adventure|Sci-Fi   59.0  4.050847
# 435                   Action|Adventure|Comedy|Sci-Fi   54.0  3.833333
# 428           Action|Adventure|Drama|Sci-Fi|Thriller   54.0  3.435185
# ...
